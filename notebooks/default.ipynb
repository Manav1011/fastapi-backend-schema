# %%
import os
import sys
from pathlib import Path

# Change working directory to the project root
project_root = Path.cwd().parent.resolve()
os.chdir(project_root)

# Ensure project root is in sys.path for imports
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from project.core.helpers.shell_setup import setup_shell
setup_shell()
# Out:
# {'settings': Settings(PROJECT_NAME='fastapi-backend', ENV='local', DEBUG=True, SECRET_KEY='change-me', DATABASE_URL='sqlite+aiosqlite:///./db.sqlite3', DATABASES='', INSTALLED_APPS=['project.apps.users'], API_PREFIX='/api/v1', CORS_ORIGINS=['http://localhost:3000', 'http://localhost:5173'], TRUSTED_HOSTS=['localhost', '127.0.0.1'], ADMIN_PATH='/admin', JWT_SECRET='change-me-too', JWT_LIFETIME_SECONDS=3600),
#  'get_settings': <functools._lru_cache_wrapper at 0x753f8d412770>,
#  'sessionmaker': async_sessionmaker(class_='AsyncSession', bind=<sqlalchemy.ext.asyncio.engine.AsyncEngine object at 0x753f700e7400>, autoflush=True, expire_on_commit=False),
#  'get_session': <function project.core.helpers.shell_setup.get_namespace.<locals>.get_session()>,
#  'get_async_session': <function project.core.db.session.get_async_session(using: 'str' = 'default') -> 'AsyncIterator[AsyncSession]'>,
#  'Base': project.core.db.base.Base,
#  'Manager': project.core.db.queryset.Manager,
#  'QuerySet': project.core.db.queryset.QuerySet,
#  'registry': AppRegistry(installed_apps=['project.apps.users'], imported=['project.apps.users'], routers=[<fastapi.routing.APIRouter object at 0x753f7009fd60>]),
#  'User': project.apps.users.models.User,
#  'run': <function project.core.helpers.shell_setup.run(coro)>}

# %%
async with get_session() as session:
    users = await User.objects.all(session)
    print(users)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:146, in AsyncAdapt_aiosqlite_cursor.execute(self, operation, parameters)
#     145 except Exception as error:
# --> 146     self._adapt_connection._handle_exception(error)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:298, in AsyncAdapt_aiosqlite_connection._handle_exception(self, error)
#     297 else:
# --> 298     raise error
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:128, in AsyncAdapt_aiosqlite_cursor.execute(self, operation, parameters)
#     127 else:
# --> 128     self.await_(_cursor.execute(operation, parameters))
#     130 if _cursor.description:
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:130, in await_only(awaitable)
#     126 # returns the control to the driver greenlet passing it
#     127 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     128 # switches back to this greenlet with the result of awaitable that is
#     129 # then returned to the caller (or raised as error)
# --> 130 return current.driver.switch(awaitable)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:195, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     192 try:
#     193     # wait for a coroutine from await_only and then return its
#     194     # result back to it.
# --> 195     value = await result
#     196 except BaseException:
#     197     # this allows an exception to be raised within
#     198     # the moderated greenlet so that it can continue
#     199     # its expected flow.
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/cursor.py:48, in Cursor.execute(self, sql, parameters)
#      47     parameters = []
# ---> 48 await self._execute(self._cursor.execute, sql, parameters)
#      49 return self
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/cursor.py:40, in Cursor._execute(self, fn, *args, **kwargs)
#      39 """Execute the given function on the shared connection's thread."""
# ---> 40 return await self._conn._execute(fn, *args, **kwargs)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/core.py:132, in Connection._execute(self, fn, *args, **kwargs)
#     130 self._tx.put_nowait((future, function))
# --> 132 return await future
#
# File /usr/lib/python3.10/asyncio/futures.py:285, in Future.__await__(self)
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#
# File /usr/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# File /usr/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/core.py:115, in Connection.run(self)
#     114 LOG.debug("executing %s", function)
# --> 115 result = function()
#     116 LOG.debug("operation %s completed", function)
#
# OperationalError: no such table: users
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 async with get_session() as session:
# ----> 2     users = await User.objects.all(session)
#       3     print(users)
#
# File ~/Documents/fastapi-backend-schema/project/core/db/queryset.py:536, in Manager.all(self, session)
#     534 async def all(self, session: AsyncSession) -> list[ModelType]:
#     535     """Get all objects."""
# --> 536     return await QuerySet(self.model, session).all()
#
# File ~/Documents/fastapi-backend-schema/project/core/db/queryset.py:61, in QuerySet.all(self)
#      54 """
#      55 Return all objects (Django-like).
#      56
#      57 Returns:
#      58     List of all model instances
#      59 """
#      60 query = self._get_query()
# ---> 61 result = await self.session.execute(query)
#      62 return list(result.scalars().all())
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/ext/asyncio/session.py:455, in AsyncSession.execute(self, statement, params, execution_options, bind_arguments, **kw)
#     452 else:
#     453     execution_options = _EXECUTE_OPTIONS
# --> 455 result = await greenlet_spawn(
#     456     self.sync_session.execute,
#     457     statement,
#     458     params=params,
#     459     execution_options=execution_options,
#     460     bind_arguments=bind_arguments,
#     461     **kw,
#     462 )
#     463 return await _ensure_sync_result(result, self.execute)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:200, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     195     value = await result
#     196 except BaseException:
#     197     # this allows an exception to be raised within
#     198     # the moderated greenlet so that it can continue
#     199     # its expected flow.
# --> 200     result = context.throw(*sys.exc_info())
#     201 else:
#     202     result = context.switch(value)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2308, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2247 def execute(
#    2248     self,
#    2249     statement: Executable,
#    (...)
#    2255     _add_event: Optional[Any] = None,
#    2256 ) -> Result[Any]:
#    2257     r"""Execute a SQL expression construct.
#    2258
#    2259     Returns a :class:`_engine.Result` object representing
#    (...)
#    2306
#    2307     """
# -> 2308     return self._execute_internal(
#    2309         statement,
#    2310         params,
#    2311         execution_options=execution_options,
#    2312         bind_arguments=bind_arguments,
#    2313         _parent_execute_state=_parent_execute_state,
#    2314         _add_event=_add_event,
#    2315     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2190, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2185     return conn.scalar(
#    2186         statement, params or {}, execution_options=execution_options
#    2187     )
#    2189 if compile_state_cls:
# -> 2190     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2191         self,
#    2192         statement,
#    2193         params or {},
#    2194         execution_options,
#    2195         bind_arguments,
#    2196         conn,
#    2197     )
#    2198 else:
#    2199     result = conn.execute(
#    2200         statement, params or {}, execution_options=execution_options
#    2201     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/orm/context.py:293, in AbstractORMCompileState.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#     283 @classmethod
#     284 def orm_execute_statement(
#     285     cls,
#    (...)
#     291     conn,
#     292 ) -> Result:
# --> 293     result = conn.execute(
#     294         statement, params or {}, execution_options=execution_options
#     295     )
#     296     return cls.orm_setup_cursor_result(
#     297         session,
#     298         statement,
#    (...)
#     302         result,
#     303     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:146, in AsyncAdapt_aiosqlite_cursor.execute(self, operation, parameters)
#     144         self._cursor = _cursor
#     145 except Exception as error:
# --> 146     self._adapt_connection._handle_exception(error)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:298, in AsyncAdapt_aiosqlite_connection._handle_exception(self, error)
#     294     raise self.dbapi.sqlite.OperationalError(
#     295         "no active connection"
#     296     ) from error
#     297 else:
# --> 298     raise error
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/dialects/sqlite/aiosqlite.py:128, in AsyncAdapt_aiosqlite_cursor.execute(self, operation, parameters)
#     126     self.await_(_cursor.execute(operation))
#     127 else:
# --> 128     self.await_(_cursor.execute(operation, parameters))
#     130 if _cursor.description:
#     131     self.description = _cursor.description
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:130, in await_only(awaitable)
#     121     raise exc.MissingGreenlet(
#     122         "greenlet_spawn has not been called; can't call await_only() "
#     123         "here. Was IO attempted in an unexpected place?"
#     124     )
#     126 # returns the control to the driver greenlet passing it
#     127 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     128 # switches back to this greenlet with the result of awaitable that is
#     129 # then returned to the caller (or raised as error)
# --> 130 return current.driver.switch(awaitable)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:195, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     191 switch_occurred = True
#     192 try:
#     193     # wait for a coroutine from await_only and then return its
#     194     # result back to it.
# --> 195     value = await result
#     196 except BaseException:
#     197     # this allows an exception to be raised within
#     198     # the moderated greenlet so that it can continue
#     199     # its expected flow.
#     200     result = context.throw(*sys.exc_info())
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/cursor.py:48, in Cursor.execute(self, sql, parameters)
#      46 if parameters is None:
#      47     parameters = []
# ---> 48 await self._execute(self._cursor.execute, sql, parameters)
#      49 return self
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/cursor.py:40, in Cursor._execute(self, fn, *args, **kwargs)
#      38 async def _execute(self, fn, *args, **kwargs):
#      39     """Execute the given function on the shared connection's thread."""
# ---> 40     return await self._conn._execute(fn, *args, **kwargs)
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/core.py:132, in Connection._execute(self, fn, *args, **kwargs)
#     128 future = asyncio.get_event_loop().create_future()
#     130 self._tx.put_nowait((future, function))
# --> 132 return await future
#
# File /usr/lib/python3.10/asyncio/futures.py:285, in Future.__await__(self)
#     283 if not self.done():
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#     287     raise RuntimeError("await wasn't used with future")
#
# File /usr/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# File /usr/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/Documents/fastapi-backend-schema/venv/lib/python3.10/site-packages/aiosqlite/core.py:115, in Connection.run(self)
#     113 try:
#     114     LOG.debug("executing %s", function)
# --> 115     result = function()
#     116     LOG.debug("operation %s completed", function)
#     117     future.get_loop().call_soon_threadsafe(set_result, future, result)
#
# OperationalError: (sqlite3.OperationalError) no such table: users
# [SQL: SELECT users.is_staff, users.date_joined, users.last_login, users.id, users.email, users.hashed_password, users.is_active, users.is_superuser, users.is_verified
# FROM users]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
